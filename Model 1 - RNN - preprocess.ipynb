# %%
import numpy as np
import torch
import pandas as pd
import pickle as pkl
import operator

# %%
data = pd.read_csv("data/pair_sentences.csv", sep="|", index_col=0)
# Out:
# /home/lucas/anaconda2/lib/python2.7/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
data
# Out:
#                                          previous_sentence  \
# 0        The Benefits of a Sydney Corporate Fitness Pro...
# 1                            Were chickens firing rockets?
# 2        Adobe, Apple working together on Flash for iPhone
# 3                   where Workers take the most sick days.
# 4        I've been searching for the answer for this fo...
# 5        It's obviously tracks from a giant water tract...
# 6                obviously its the folds in the google map
# 7                                    Answer: It's a quilt.
# 8                                                   Lupus.
# 9        It's a tell-tale sign where the 3rd Stargate i...
# 10                I think they got lazy and scanned a map.
# 11       Runes laid out by the vikings to keep the wate...
# 12                              live maps doesn't have it.
# 13                              tracks left by icebreakers
# 14                                                    fake
# 15                      It's just God, testing your faith.
# 16                                       it's a conspiracy
# 17                       It's crop circles.....under water
# 18       It's to let the Old Ones know where Dagon lies...
# 19                                              The ocean.
# 20                       Well, it's obviously google maps!
# 21              It's a google map of my blue toilet paper.
# 22       chemtrail shadows (the trails themselves have ...
# 23                           Religion must have the answer
# 24       The world consists of a rich, chocolatey core,...
# 25                      It's Russia's nuclear test site...
# 26       it's where the world was sewn together after i...
# 27                                     It's Red Route One.
# 28                                                      42
# 29                                       Tracks of Cthulhu
# ...                                                    ...
# 6607132  The frustration Dano is holding back is hilarious
# 6607133   Got a good feeling we're gonna get a shorty here
# 6607134  Best part of this game so far is Deb looking g...
# 6607135                                                Wow
# 6607136  sorry I'm late, I was looking for Tim Peel's b...
# 6607137  HOW THE FUCK DO THEY NOT CALL SEIDENBERG BUT T...
# 6607138             Wow that almost gave me a heart attack
# 6607139                         They should fight the refs
# 6607140                             Pull Kinky for funsies
# 6607141  What in the actual fuck kinda of positioning w...
# 6607142  Hynes with a few choice words as he walks off....
# 6607143                    Kinkaid gives up huge rebounds.
# 6607144                   Hynes looking straight disgusted
# 6607145  Maybe Hynes will get so angry he will accident...
# 6607146                                     Down in front!
# 6607147  We spend so much time in the penalty box we sh...
# 6607148  5 of the 8 assists Zacha has in the last 10 ca...
# 6607149  lovejoy just making sure we use our makeup cal...
# 6607150  Ivanka Trump and Jared Kushner Still Benefitin...
# 6607151  Our spiral into a banana republic continues, I...
# 6607152             business worth as Much as $740 Million
# 6607153  But according the Chafetz, they are rich so th...
# 6607154  Breaking news: daughter of political figure ha...
# 6607155  I was just wondering what to watch on TV and f...
# 6607156                2017: When nepotism came to America
# 6607157                  Say it with me, C O M P L I C I T
# 6607158          There's always money in the banana stand.
# 6607159                            Conservatives are liars
# 6607160  "I did not have sex with that woman".--Bill Cl...
# 6607161                 You think Trump is a conservative?
#
#                                                   sentence  label
# 0        Maybe if we eliminated the minimum wage, peopl...      1
# 1        Well we do know that geese have taken down a p...      1
# 2        Considering the MacOS X plug-in is a complete ...      0
# 3        Other indicator of America's superior health c...      1
# 4        It's obviously tracks from a giant water tract...      0
# 5                obviously its the folds in the google map      0
# 6                                    Answer: It's a quilt.      0
# 7                                                   Lupus.      0
# 8        It's a tell-tale sign where the 3rd Stargate i...      0
# 9                 I think they got lazy and scanned a map.      0
# 10       Runes laid out by the vikings to keep the wate...      0
# 11                              live maps doesn't have it.      0
# 12                              tracks left by icebreakers      0
# 13                                                    fake      0
# 14                      It's just God, testing your faith.      0
# 15                                       it's a conspiracy      0
# 16                       It's crop circles.....under water      0
# 17       It's to let the Old Ones know where Dagon lies...      0
# 18                                              The ocean.      0
# 19                       Well, it's obviously google maps!      0
# 20              It's a google map of my blue toilet paper.      0
# 21       chemtrail shadows (the trails themselves have ...      0
# 22                           Religion must have the answer      1
# 23       The world consists of a rich, chocolatey core,...      0
# 24                      It's Russia's nuclear test site...      0
# 25       it's where the world was sewn together after i...      0
# 26                                     It's Red Route One.      0
# 27                                                      42      0
# 28                                       Tracks of Cthulhu      0
# 29       Either a quilt, or random unexplainable artifa...      0
# ...                                                    ...    ...
# 6607132   Got a good feeling we're gonna get a shorty here      0
# 6607133  Best part of this game so far is Deb looking g...      0
# 6607134                                                Wow      0
# 6607135  sorry I'm late, I was looking for Tim Peel's b...      0
# 6607136  HOW THE FUCK DO THEY NOT CALL SEIDENBERG BUT T...      0
# 6607137             Wow that almost gave me a heart attack      0
# 6607138                         They should fight the refs      0
# 6607139                             Pull Kinky for funsies      0
# 6607140  What in the actual fuck kinda of positioning w...      0
# 6607141  Hynes with a few choice words as he walks off....      0
# 6607142                    Kinkaid gives up huge rebounds.      0
# 6607143                   Hynes looking straight disgusted      0
# 6607144  Maybe Hynes will get so angry he will accident...      0
# 6607145                                     Down in front!      0
# 6607146  We spend so much time in the penalty box we sh...      0
# 6607147  5 of the 8 assists Zacha has in the last 10 ca...      0
# 6607148  lovejoy just making sure we use our makeup cal...      0
# 6607149  I didn't quite catch the hook, it looked more ...      0
# 6607150  Our spiral into a banana republic continues, I...      0
# 6607151             business worth as Much as $740 Million      0
# 6607152  But according the Chafetz, they are rich so th...      1
# 6607153  Breaking news: daughter of political figure ha...      0
# 6607154  I was just wondering what to watch on TV and f...      0
# 6607155                2017: When nepotism came to America      0
# 6607156                  Say it with me, C O M P L I C I T      0
# 6607157          There's always money in the banana stand.      0
# 6607158  Yeah I think if this potential conflict of int...      0
# 6607159  "I did not have sex with that woman".--Bill Cl...      0
# 6607160                 You think Trump is a conservative?      0
# 6607161  Right, left, lib, con, black, white; rich peop...      0
#
# [6607162 rows x 3 columns]

# %% [markdown]
# ## For now we take the train set and divide it into train - val - test
# ## Letter the test set will be the same as in the paper

# %%
train = data.ix[:3964297]
val = data.ix[3964297:5285729]
test = data.ix[5285729:]
# Out:
# /home/lucas/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
class Dictionary(object):
    def __init__(self):
        self.unknown = "<UNK>"
        self.wordCount = {}
        self.word2idx = {self.unknown:0}
        self.idx2word = [self.unknown]
        
    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        
        self.wordCount[word] = self.wordCount.get(word, 0) + 1
        return self.word2idx[word]
    
    def reoder(self):
        # the word index is dependent on its number of occurence, for triming voc.
        sorted_x = sorted(self.wordCount.items(), key=operator.itemgetter(1), reverse=True)
        new_word2idx = {self.unknown:0}
        new_idx2word = [self.unknown]
        
        for key_value in sorted_x:
            word = key_value[0]
            new_idx2word.append(word)
            new_word2idx[word] = len(self.idx2word) - 1
            
        self.word2idx = new_word2idx
        self.idx2word = new_idx2word
            
    def get_index(self, word):
        return self.word2idx.get(word, self.unknown)
        
    def __len__(self):
        return len(self.idx2word)

class Corpus(object):
    def __init__(self, train, val, test):
        self.dictionary = Dictionary()
        self.train = train
        self.valid = val
        self.test = test

    def tokenize(self):
        """Get all words in train set, set unseen words in val / test to UNK."""
        for row in range(self.train.shape[0]):
            elem = self.train.ix[row]
            words = str(elem["previous_sentence"]).split(" ") + ['<eos>'] + str(elem["sentence"]).split(" ") + ['<eos>']
            
            for word in words:
                self.dictionary.add_word(word)
                    
    def write(self, path, dataset):        
        with open(path, 'w+') as f:
            for row in range(dataset.shape[0]):
                elem = self.train.ix[row]
                line = ""
                words = str(elem["previous_sentence"]).split() + ['<eos>']
                for word in words:
                    line += str(self.dictionary.get_index(word)) + " "
                    
                line += ", "
                
                words = str(elem["sentence"]).split() + ['<eos>']
                for word in words:
                    line += str(self.dictionary.get_index(word)) + " "
                
                line += ", "
                line += str(elem["label"])
                f.write(line + "\n")

# %%
corpus = Corpus(train, val, test)

# %%
print("Tokenize ... ")
# self.tokenize()
corpus.dictionary.wordCount = pkl.load(open('data/rnn/wordcount.pkl', 'r'))
corpus.dictionary.idx2word = pkl.load(open('data/rnn/idx2word.pkl', 'r'))
# corpus.dictionary.word2idx = pkl.load(open('data/rnn/word2idx.pkl', 'r'))
# Out:
# Tokenize ...

# %%
word2idx = {}
for idx in range(len(corpus.dictionary.idx2word)):
    word2idx[corpus.dictionary.idx2word[idx]] = idx

# %%
corpus.dictionary.word2idx = word2idx

# %%
# corpus.dictionary.reoder()
print("Write train ...")
corpus.write("data/rnn/train-tokenized.txt", corpus.train)
# Out:
# Write train ...

# %%
print("Write val + test ...")
corpus.write("data/rnn/val-tokenized.txt", corpus.valid)
print("Test ...")
corpus.write("data/rnn/test-tokenized.txt", corpus.test)
# Out:
# Write val + test ...
# Test ...

# %%
pkl.dump(word2idx, open('data/rnn/word2idx.pkl', 'w+'))

# %%
corpus.dictionary.wordCount.get('bed', 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-effbb4354656> in <module>()
# ----> 1 corpus.dictionary.wordCount.get('bed', 0)
#
# NameError: name 'corpus' is not defined

# %%
corpus.dictionary.word2idx['tile']
# Out:
# 15987

# %%
criterion = nn.BCELoss()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-301f24f1cf49> in <module>()
# ----> 1 criterion = nn.BCELoss()
#
# NameError: name 'nn' is not defined
